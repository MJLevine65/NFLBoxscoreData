# %%
import sys
sys.path.append('../')
from src.database.DatabaseAccessor import DatabaseAccessor
dbaccessor = DatabaseAccessor()

# %% [markdown]
# Create Tables

# %%
# Create GameInfo Table
table_columns = [
    "game_id CHAR(12) PRIMARY KEY",
    "year INT NOT NULL",
    "week INT NOT NULL",
    "home CHAR(3) NOT NULL",
    "away CHAR(3) NOT NULL",
    "date DATE NOT NULL",
    "start_time TIME",
    "stadium VARCHAR(40)",
    "attendance INT",
    "won_toss VARCHAR(30)",
    "won_ot_toss VARCHAR(30)",
    "roof VARCHAR(40)",
    "surface VARCHAR(40)",
    "duration INT",
    "vegas_line VARCHAR(40)",
    "over_under VARCHAR(40)",
    "temprature INT",
    "wind_speed INT",
    "humidity INT",
    "wind_chill INT",
    "super_bowl_mvp VARCHAR(50)"
]

dbaccessor.drop_table("game_info")
dbaccessor.create_table("game_info", ", ".join(table_columns))

# %%
# Create Team Game Log Table
table_columns = [
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, team)",
    "opponent CHAR(3) NOT NULL",
    "home_team BOOLEAN NOT NULL",
    "result CHAR(1) NOT NULL",
    "coach VARCHAR(50) NOT NULL",
    "score INT NOT NULL",
    "opponent_score INT NOT NULL",
    "team_record VARCHAR(10) NOT NULL",
    "first_downs INT",
    "third_downs INT",
    "third_down_conversions INT",
    "fourth_downs INT",
    "fourth_down_conversions INT",
    "possession INT",
    "passing_attempts INT",
    "passing_completions INT",
    "passing_yds INT",
    "passing_tds INT",
    "passing_yds_allowed INT",
    "passing_tds_allowed INT",
    "rushing_attempts INT",
    "rushing_yds INT",
    "rushing_tds INT",
    "rushing_yds_allowed INT",
    "rushing_tds_allowed INT",
    "offensive_interceptions INT",
    "defensive_interceptions INT",
    "fumbles INT",
    "fumbles_lost INT",
    "forced_fumbles INT",
    "forced_fumbles_recovered INT",
    "sacks INT",
    "sack_yds INT",
    "sacks_taken INT",
    "sack_yds_lost INT",
    "penalties INT",
    "penalty_yds INT"
]

dbaccessor.drop_table("team_gamelogs")
dbaccessor.create_table("team_gamelogs", ", ".join(table_columns),primary_index="(game_id, team)")

# %%
# Create Passing Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "completions INT",
    "attempts INT",
    "yards INT",
    "air_yds INT",
    "int_air_yds INT",
    "yds_after_catch INT",
    "long INT",
    "first_downs INT",
    "touchdowns INT",
    "scrambles INT",
    "interceptions INT",
    "drops INT",
    "poor_throws INT",
    "blitzes INT",
    "hurries INT",
    "hits INT",
    "pressures INT",
    "sacks INT",
    "sack_yds INT",
    "rating REAL"

]

dbaccessor.drop_table("passing_gamelogs")
dbaccessor.create_table("passing_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create receiving Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "targets INT",
    "receptions INT",
    "yards INT",
    "air_yds INT",
    "yds_after_catch INT",
    "adot REAL",
    "long INT",
    "first_downs INT",
    "touchdowns INT",
    "broken_tackles INT",
    "interceptions INT",
    "drops INT",
    "rating REAL"

]

dbaccessor.drop_table("receiving_gamelogs")
dbaccessor.create_table("receiving_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create rushing Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "attempts INT",
    "yards INT",
    "yds_before_contact INT",
    "yds_after_contact INT",
    "long INT",
    "first_downs INT",
    "touchdowns INT",
    "broken_tackles INT"
]

dbaccessor.drop_table("rushing_gamelogs")
dbaccessor.create_table("rushing_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create defense Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "targets INT",
    "rec_allowed INT",
    "rec_yds_allowed INT",
    "air_yds INT",
    "yac_allowed INT",
    "rec_tds_allowed INT",
    "interceptions INT",
    "interception_yds INT",
    "interception_long INT",
    "pick_sixes INT",
    "passes_defended INT",
    "rating_allowed REAL",
    "blitzes INT",
    "hurries INT",
    "knockdowns INT",
    "qb_hits INT",
    "sacks REAL",
    "solo_tackles INT",
    "assisted_tackles INT",
    "missed_tackles INT",
    "tackles_for_loss INT",
    "fumble_rec INT",
    "fumble_yds INT",
    "fumble_rec_tds INT",
    "forced_fumbles INT"
]

dbaccessor.drop_table("defense_gamelogs")
dbaccessor.create_table("defense_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create fumble Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "fumbles INT",
    "fumbles_lost INT"
]

dbaccessor.drop_table("fumble_gamelogs")
dbaccessor.create_table("fumble_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create kicking Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "xp_made INT",
    "xp_attempts INT",
    "fg_made INT",
    "fg_attempts INT",
    "punts INT",
    "punt_yds INT",
    "punt_long INT"
]

dbaccessor.drop_table("kicking_gamelogs")
dbaccessor.create_table("kicking_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create returns Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "kick_returns INT",
    "kick_ret_yds INT",
    "kick_ret_tds INT",
    "kick_ret_long INT",
    "punt_returns INT",
    "punt_ret_yds INT",
    "punt_ret_tds INT",
    "punt_ret_long INT"
]

dbaccessor.drop_table("return_gamelogs")
dbaccessor.create_table("return_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create snaps Game Log Table
table_columns = [
    "player VARCHAR(10) NOT NULL",
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "PRIMARY KEY(game_id, player)",
    "starter BOOLEAN",
    "pos VARCHAR(5)",
    "offense INT",
    "off_pct REAL",
    "defense INT",
    "def_pct REAL",
    "special_teams INT",
    "st_pct REAL"
]

dbaccessor.drop_table("snap_gamelogs")
dbaccessor.create_table("snap_gamelogs", ", ".join(table_columns),primary_index="(game_id, player)")

# %%
# Create drives  Table
table_columns = [
    "game_id CHAR(12) NOT NULL",
    "team CHAR(3) NOT NULL",
    "drive_num INT NOT NULL",
    "PRIMARY KEY(game_id, team, drive_num)",
    "quarter INT",
    "start_time INTERVAL",
    "start_loc VARCHAR(6)",
    "plays INT",
    "time INTERVAL",
    "net_yds INT",
    "result VARCHAR(20)"
]

dbaccessor.drop_table("drives")
dbaccessor.create_table("drives", ", ".join(table_columns),primary_index="(game_id, team, drive_num)")

# %%
# Create pbp Table
table_columns = [
    "play_id VARCHAR(15) PRIMARY KEY",
    "game_id CHAR(12) NOT NULL",
    "home_score INT",
    "away_score INT",
    "quarter VARCHAR(2) NOT NULL",
    "time INTERVAL",
    "down INT",
    "yds_to_go INT",
    "location VARCHAR(6)",
    "description TEXT",
    "players TEXT",
    # "play_type VARCHAR(20)",
    # "play_result VARCHAR(30)",
    # "net_yds INT",
    "epb REAL",
    "epa REAL"
]

dbaccessor.drop_table("pbp_data")
dbaccessor.create_table("pbp_data", ", ".join(table_columns))
